# %%
import base64
import hashlib
from supabase import create_client, Client

# ========= YOUR DATA =========

SUPABASE_URL = "https://ackzsytbrkhoticwvqkg.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImFja3pzeXRicmtob3RpY3d2cWtnIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc1Nzg2NDc5MSwiZXhwIjoyMDczNDQwNzkxfQ.LYX8OSHZl5SRilGndjZE-5huwWSficeOOLzLtnL_SRs"

# Base64 encoded salt used for hashing (must be the same for all)
SALT_B64 = "GbXOwsKls7dGtdwlsgNDFX11itzdUCdCaQ50LCjbi94="


# ========= HASH FUNCTION =========
def pbkdf2_hash(password: str, salt_b64: str) -> str:
    """Return PBKDF2-HMAC-SHA256 hash using base64 salt."""
    salt = base64.b64decode(salt_b64)
    dk = hashlib.pbkdf2_hmac("sha256", password.encode("utf-8"), salt, 200_000)
    return base64.b64encode(dk).decode("utf-8")


# ========= SUPABASE CLIENT =========
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)


# ========= INSERT USERS =========
def register_all_users():
    for username, password in VALID_USERNAME_PASSWORD_PAIRS.items():
        name = USERNAME_TO_MEMBERNAME.get(username, username)
        hashed_pw = pbkdf2_hash(password, SALT_B64)

        data = {
            "username": username,
            "password": hashed_pw,
            "name": name,
            "email": None,
            "reset_code": None,
            "is_admin": False,
        }

        try:
            response = supabase.table("authentication").insert(data).execute()
            if response.data:
                print(f"Inserted: {username}")
            else:
                print(f"Failed to insert {username}: {response}")
        except Exception as e:
            print(f"Error inserting {username}: {e}")


if __name__ == "__main__":
    register_all_users()
# Out:
# Inserted: astdew
# Inserted: Julie Vanacker
# Inserted: jellelamaire
# Inserted: Vince
# Inserted: heloise.brackenier
# Inserted: Lisa__vdh
# Inserted: JuulE
# Inserted: emmawillemen
# Inserted: LudovicB
# Inserted: louismsn
# Inserted: Fredric
# Inserted: Kamiel
# Inserted: simdeb
# Inserted: Emmavanmarcke
# Inserted: KorneelDoise
# Inserted: Theodorevansteelant
# Inserted: ThomasVDH
# Inserted: JorenBoons
# Inserted: Thibaultv
# Inserted: Investia
# Inserted: ealgoet
# Inserted: charlottevantricht
# Inserted: sabbe.arthur
# Inserted: Felix Cornelis
# Inserted: annelien
# Inserted: Balesse
# Inserted: Olivier
# Inserted: michiel.depaepe
# Inserted: simzenner
# Inserted: casteleyn.karel@gmail.com
# Inserted: quinten.casteleyn@hotmail.com
# Inserted: haroldvanherpe
# Inserted: KoenVA
# Inserted: lenders.v
# Inserted: ag.santens
# Inserted: Fil
# Inserted: Arno Vermote
# Inserted: Liodf99
# Inserted: jerome
# Inserted: Ellen De Schrijver
# Inserted: SenneWellens
# ...

# %%
USERNAME_TO_MEMBERNAME = {"astdew" : "Astrid Dewever", 
"Julie Vanacker" : "Julie Vanacker", 
"jellelamaire": "Jelle Lamaire", 
"Vince": "Vince Coppens", 
"heloise.brackenier" : "Heloise Brackenier", 
"Lisa__vdh" : "Lisa Van den Houte", 
"JuulE" : "Juul Erregat", 
"emmawillemen": "Emma Willemen", 
"LudovicB" :  "Ludovic Brackenier", 
"louismsn" : "Louis Meersman", 
"Fredric" : "Fredric Demeyre", 
"Kamiel" : "Kamiel Boons", 
"simdeb" : "Simon De Baere", 
"Emmavanmarcke":"Emma Van Marcke", 
"KorneelDoise":"Korneel Doise", 
"Theodorevansteelant" : "Theodore Vansteelant", 
"ThomasVDH" : "Thomas Vanderhaeghe", 
"JorenBoons" : "Joren Boons", 
"Thibaultv" : "Thibault Valcke",
"Investia" : "Arnaud Nelis", 
"ealgoet" : "Emmy Algoet", 
"charlottevantricht" : "Charlotte Van Tricht", 
"sabbe.arthur" : "Arthur Sabbe", 
"Felix Cornelis" : "Felix Cornelis", 
"annelien" : "Annelien Crijns", 
"Balesse":"Laurent Balesse", 
"Olivier":"Olivier Deforche", 
"michiel.depaepe":"Michiel De Paepe", 
"simzenner":"Simon Zenner", 
"casteleyn.karel@gmail.com":"Karel Casteleyn", 
"quinten.casteleyn@hotmail.com":"Quinten Casteleyn",
"haroldvanherpe": "Harold Vanherpe", 
"KoenVA":"Koen Van Asch", 
"lenders.v":"Vincent Lenders", 
"ag.santens":"Anne-Gaëlle Santens", 
"Fil":"Filip Roest", 
"Arno Vermote":"Arno Vermote", 
"Liodf99":"Lionel Defauw", 
"jerome":"Jerome Billiet", 
"Ellen De Schrijver":"Ellen De Schrijver", 
"SenneWellens" : "Senne Wellens", 
"theoduplat@gmail.com":"Theodore Duplat", 
"Gilles Bodart" : "Gilles Bodart", 
"Baku1942" : "Artus Missorten de Crombrugghe", 
"chloegeuten" : "Chloé Geuten", 
"kamilozkan_":"Kamil Özkan", 
"emilebomans":"Emile Bomans", 
"Daan_Vinck":"Daan Vinck", 
"Juliette Loossens":"Juliette Loossens", 
"Matthias Verghote":"Matthias Verghote", 
"Bernardfossion":"Bernard Fossion", 
"Nicolas":"Nicolas Vanherpe", 
"elliottbomans":"Elliott Bomans", 
"reneehanssens":"Renée Hanssens", 
"Nikita Voroshilov":"Nikita Voroshilov", 
"Cedric Segers" : "Cedric Segers", 
"quinten_v" : "Quinten Verougstraete", 
"maxime_st" : "Maxime Steeman", 
"maxim_sp" : "Maxime Spaas", 
"clemence_s" : "Clemence Samyn", 
"rodolphe_f": "Rodolphe Filaine"
}

# %%
VALID_USERNAME_PASSWORD_PAIRS = {"astdew":"ridever", 
"Julie Vanacker":"Investia04", 
"jellelamaire": "J3lle@Inv1stia", 
"Vince":"Warrenbuffett1", 
"heloise.brackenier": "Investia!!", 
"Lisa__vdh": "Warrenbuffet1", 
"JuulE": "Inviemnsv.5b", 
"emmawillemen": "Warrenbuffet1", 
"LudovicB": "Ikleesveel123()", 
"louismsn": "Warrenbuffet1", 
"Fredric" : "wachtwoord", 
"Kamiel" : "Kamiel2002", 
"simdeb" : "InvestiaPW",
"Emmavanmarcke" : "1nv3st1a", 
"KorneelDoise" : "KorneelInvestia19", 
"Theodorevansteelant" : "Investia1997", 
"ThomasVDH" : "America+23Me", 
"JorenBoons" : "Investia123", 
"Thibaultv" : "Lincoln3236", 
"Investia" : "Investia", 
"ealgoet" : "Algoet01", 
"charlottevantricht" : "ThitchCVT2140!", 
"sabbe.arthur" : "H1cp9n2qux5", 
"Felix Cornelis" : "Investia123", 
"annelien": "investia2020", 
"Balesse": "MBkdg1418!", 
"Olivier":"Investia123", 
"michiel.depaepe" : "WarrenBuffett", 
"simzenner":"baasjevaninvestia12!", 
"casteleyn.karel@gmail.com":"IAPluisje789+", 
"quinten.casteleyn@hotmail.com":"cercle123", 
"haroldvanherpe":"haroldinvestia", 
"KoenVA":"20KC08149!", 
"lenders.v":"Investi@VL23", 
"ag.santens":"Edouard123!", 
"Fil":"Investia", 
"Arno Vermote":"Vermo74940", 
"Liodf99":"Investia2017", 
"jerome":"Warrenbuffet1", 
"Ellen De Schrijver" : "Investia2023", 
"SenneWellens":"Recova180266!", 
"theoduplat@gmail.com":"Investia1923!", 
"Gilles Bodart" : "@Investia159", 
"Baku1942" : "#Aurum2020", 
"chloegeuten" : "Boxy009!", 
"kamilozkan_":"InvestiaRocks1234.", 
"emilebomans":"485000", 
"Daan_Vinck":"St0rmChase", 
"Juliette Loossens":"Lanjaron88!", 
"Matthias Verghote":"Investia2020", 
"Bernardfossion":"Investia2024", 
"Nicolas":"NicolasV", 
"elliottbomans":"Elliott2005", 
"reneehanssens":"Renee009", 
"Nikita Voroshilov":"Tradeinvestia212", 
"Cedric Segers":"Investia123", 
"quinten_v" : "quinten_investia2025", 
"maxime_st" : "maximest_investia2025", 
"maxim_sp" : "maximsp_investia2025", 
"clemence_s" : "clemence_investia2025", 
"rodolphe_f" : "rodolphef_investia2025"
}

# %%
import os
import base64
from supabase import create_client, Client

# ========= CONFIG =========
SUPABASE_URL = "https://ackzsytbrkhoticwvqkg.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImFja3pzeXRicmtob3RpY3d2cWtnIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc1Nzg2NDc5MSwiZXhwIjoyMDczNDQwNzkxfQ.LYX8OSHZl5SRilGndjZE-5huwWSficeOOLzLtnL_SRs"

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)


# ========= FUNCTIONS =========
def generate_reset_code() -> str:
    """Return a unique 32-character base64 reset code (URL-safe)."""
    return base64.urlsafe_b64encode(os.urandom(24)).decode('utf-8').rstrip('=')


def update_all_reset_codes():
    # Fetch all usernames
    response = supabase.table("authentication").select("username").execute()
    users = response.data

    if not users:
        print("No users found.")
        return

    used_codes = set()

    for user in users:
        username = user["username"]
        code = generate_reset_code()

        # Ensure uniqueness in this batch
        while code in used_codes:
            code = generate_reset_code()
        used_codes.add(code)

        # Update row
        update_resp = (
            supabase.table("authentication")
            .update({"reset_code": code})
            .eq("username", username)
            .execute()
        )

        if update_resp.data:
            print(f"Updated reset_code for: {username}")
        else:
            print(f"Failed to update {username}: {update_resp}")


if __name__ == "__main__":
    update_all_reset_codes()
# Out:
# Updated reset_code for: astdew
# Updated reset_code for: Julie Vanacker
# Updated reset_code for: jellelamaire
# Updated reset_code for: Vince
# Updated reset_code for: heloise.brackenier
# Updated reset_code for: Lisa__vdh
# Updated reset_code for: JuulE
# Updated reset_code for: emmawillemen
# Updated reset_code for: LudovicB
# Updated reset_code for: louismsn
# Updated reset_code for: Fredric
# Updated reset_code for: Kamiel
# Updated reset_code for: simdeb
# Updated reset_code for: Emmavanmarcke
# Updated reset_code for: KorneelDoise
# Updated reset_code for: Theodorevansteelant
# Updated reset_code for: ThomasVDH
# Updated reset_code for: JorenBoons
# Updated reset_code for: Thibaultv
# Updated reset_code for: Investia
# Updated reset_code for: ealgoet
# Updated reset_code for: charlottevantricht
# Updated reset_code for: sabbe.arthur
# Updated reset_code for: Felix Cornelis
# Updated reset_code for: annelien
# Updated reset_code for: Balesse
# Updated reset_code for: Olivier
# ...

# %%
from supabase import create_client, Client

# ========= CONFIG =========
SUPABASE_URL = "https://ackzsytbrkhoticwvqkg.supabase.co"
SUPABASE_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImFja3pzeXRicmtob3RpY3d2cWtnIiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc1Nzg2NDc5MSwiZXhwIjoyMDczNDQwNzkxfQ.LYX8OSHZl5SRilGndjZE-5huwWSficeOOLzLtnL_SRs"

supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# ========= NAME → EMAIL DICTIONARY =========
name_to_email = {
    "Astrid Dewever": "astrid@dewever.be",
    "Julie Vanacker": "julie@vanacker.be",
    "Jelle Lamaire": "jelle.lamaire@gmail.com",
    "Vince Coppens": "vince.coppens@gmail.com",
    "Alexander Genoe": "alexander.genoe@gmail.com",
    "Alexander Heeren": "alexander.heeren@hotmail.com",
    "Annelien Crijns": "annelien.crijns@gmail.com",
    "Antoine Ruzette": "antoine.ruzette@gmail.com",
    "Arnaud Nelis": "arnaudnelis1@gmail.com",
    "Charlotte Bxl": "bxl.charlotte@gmail.com",
    "Cas Ruythooren": "cas.ruythooren@hotmail.com",
    "Cedric Segers": "cedric.se@hotmail.com",
    "Cedric Vanderauwermeulen": "cedric.vanderauwermeulen@gmail.com",
    "Charles Vleurinck": "charles.vleurinck@hotmail.com",
    "Charlotte Van Tricht": "charlotte.vantricht@outlook.com",
    "Cornelis Felix": "cornelis.felix@gmail.com",
    "Cornelis Stan": "cornelis.stan@gmail.com",
    "Michiel De Paepe": "michiel.depaepe@gmail.com",
    "Ellen De Schrijver": "e.deschrijver@hotmail.com",
    "Stephane Dumont": "stephane.dumont.0@outlook.com",
    "Edouard Corthals": "edouard.corthals@gmail.com",
    "Emma Van Marcke": "emma.vanmarcke@gmail.com",
    "Emma Willemen": "emma.willemen@gmail.com",
    "Emmy Algoet": "emmy.algoet@gmail.com",
    "Eva Bulcaen": "eva.bulcaen@gmail.com",
    "Eva Struyve": "eva.struyve@outlook.com",
    "Evert Ruythooren": "ruythooren.evert@gmail.com",
    "Filip Roest": "filip.roest@gmail.com",
    "Fred Ruythooren": "fred.ruythooren@gmail.com",
    "Fredric Demeyere": "fredric.demeyere@hotmail.com",
    "Harold Vanherpe": "harold.vanherpe@gmail.com",
    "Helene Tilleman": "helene.tilleman@gmail.com",
    "Heloise Brackenier": "heloise.brackenier@gmail.com",
    "Jean Michel Bosmans": "jeanmichelbosmans@hotmail.com",
    "Jerome Billiet": "jerome.billiet@hotmail.com",
    "Joren Balt": "joren.balt@gmail.com",
    "Joren Boons": "joren.boons@hotmail.com",
    "Juul Erregat": "juul.erregat1@gmail.com",
    "Kamiel Boons": "kamiel.boons.kb@gmail.com",
    "Karel Casteleyn": "karel.casteleyn@hotmail.com",
    "Laurent Balesse": "laurent@balesse.be",
    "Vincent Lenders": "lenders.vincent@gmail.com",
    "Lionel Defauw": "lionel.defauw@gmail.com",
    "Lisa Van den Houte": "lisa.vandenhoute@gmail.com",
    "Matthias Verghote": "matthiasverghote@gmail.com",
    "Mat Vancauwenberge": "matvancauwenberge@gmail.com",
    "Louis Meersman": "meersman.louis@gmail.com",
    "Olivier Deforche": "deforche.olivier@hotmail.com",
    "Quinten Casteleyn": "quinten.casteleyn@hotmail.com",
    "Quinten Vanhinsberg": "quintenvanhinsberg@gmail.com",
    "Arthur Sabbe": "sabbe.arthur@gmail.com",
    "Sander Van Bouwel": "sander.van.bouwel@hotmail.com",
    "Senne Wellens": "senne.wellens@hotmail.com",
    "Simon De Baere": "simon.debaere@gmail.com",
    "Simon Zenner": "simon.zenner@hotmail.com",
    "Stef Boeckx Voorspoels": "stefboeckxvoorspoels@gmail.com",
    "Nicolas Stevens": "stevens.nicolas1@gmail.com",
    "Sylvia Debois": "sylvia.debois@outlook.com",
    "Theodore Vansteelant": "theodorevansteelant@gmail.com",
    "Theodore Duplat": "theoduplat@gmail.com",
    "Thibault Valcke": "thibault_valcke@hotmail.com",
    "Thomas Vanderhaeghe": "thomasvanderhaeghe@hotmail.com",
    "Koen Van Asch": "vanaschkoen@gmail.com",
    "Gilles Bodart": "bodartgilles@gmail.com",
    "Jori Geysen": "geysen.jori@gmail.com",
    "Ludovic Brackenier": "ludovic.brackenier@gmail.com",
    "Margaux De Graeve": "degraevemargaux@gmail.com",
    "Chloé Geuten": "chloegeuten@gmail.com",
    "Artus Missorten de Crombrugghe": "tabletartus@gmail.com",
    "Emile Bomans": "emilebomans.2003@gmail.com",
    "Juliette Loossens": "juliette.loossens@gmail.com",
    "Kamil Özkan": "kamilozkan.ko@gmail.com",
    "Daan Vinck": "daan.vinck@icloud.com",
    "Bernard Fossion": "bernardfossion5@gmail.com",
    "Elliott Bomans": "elliottbomans@gmail.com",
    "Nicolas Vanherpe": "nicolas.vanherpe@gmail.com",
    "Renée Hanssens": "renee.hanssens@gmail.com",
    "Nikita Voroshilov": "nikita.voroshilov28@gmail.com",
    "Rodolphe Filaine": "rodolphe.filaine@gmail.com",
    "Quinten Verougstraete": "quinten.verougstraete@gmail.com",
    "Maxime Steeman": "steemanmaxime@gmail.com",
    "Maxim Spaas": "maxim.spaas1@gmail.com"
}

# ========= UPDATE LOOP =========
for name, email in name_to_email.items():
    try:
        response = (
            supabase.table("authentication")
            .update({"email": email})
            .eq("name", name)
            .execute()
        )

        if response.data:
            print(f"✅ Updated {name}: {email}")
        else:
            print(f"⚠️ No match found for name '{name}' in table")
    except Exception as e:
        print(f"❌ Failed to update {name}: {e}")
# Out:
# ✅ Updated Astrid Dewever: astrid@dewever.be
# ✅ Updated Julie Vanacker: julie@vanacker.be
# ✅ Updated Jelle Lamaire: jelle.lamaire@gmail.com
# ✅ Updated Vince Coppens: vince.coppens@gmail.com
# ⚠️ No match found for name 'Alexander Genoe' in table
# ⚠️ No match found for name 'Alexander Heeren' in table
# ✅ Updated Annelien Crijns: annelien.crijns@gmail.com
# ⚠️ No match found for name 'Antoine Ruzette' in table
# ✅ Updated Arnaud Nelis: arnaudnelis1@gmail.com
# ⚠️ No match found for name 'Charlotte Bxl' in table
# ⚠️ No match found for name 'Cas Ruythooren' in table
# ✅ Updated Cedric Segers: cedric.se@hotmail.com
# ⚠️ No match found for name 'Cedric Vanderauwermeulen' in table
# ⚠️ No match found for name 'Charles Vleurinck' in table
# ✅ Updated Charlotte Van Tricht: charlotte.vantricht@outlook.com
# ⚠️ No match found for name 'Cornelis Felix' in table
# ⚠️ No match found for name 'Cornelis Stan' in table
# ✅ Updated Michiel De Paepe: michiel.depaepe@gmail.com
# ...
